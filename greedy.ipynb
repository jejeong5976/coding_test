# %% [markdown]
# 1. **곱하기 혹은 더하기**
#
#     각 자리가 숫자(0-9)로만 이루어진 문자열 S가 주어졌을 때, 왼쪽부터 오른쪽으로 하나씩 모든 숫자를 확인하면 숫자 사이에 ‘x’ 혹은 ‘+’ 연산자를 넣어 결과적으로 만들어질 수 있는 가장 큰 수를 구하는 프로그램을 작성하시오. 단, +보다 x를 먼저 계산하는 일반적인 방식과는 달리, 모든 연산은 왼쪽에서부터 순서대로 이루어진다고 가정.
#
#     예시) 02984라는 문자열로 만들 수 있는 가장 큰 수는 ((((0+2)*9)*8)*4) = 576입니다. 또한 만들어질 수 있는 가장 큰 수는 항상 20억 이상의 정수가 되도록 입력이 주어집니다.
#
#     입력 예시 1
#
#         02984
#     출력 예시 1
#
#         576
#
#     입력 예시 2
#
#         567
#     출력 예시 2
#
#         210

# %%
# 아이디어: x를 할 때 가장 큰 수가 됨, +를 할 때는 한 항이 0 or 1인 경우에만.
num = map(int, input())
num_list = [i for i in num]

# 시간 복잡도: for문
max_val = num_list[0]
if len(num_list)==1:
    return max_val
for idx in range(1, len(num_list)):
    if max_val <= 1 or num_list[idx] <= 1:
        max_val+= num_list[idx]
    else:
        max_val *= num_list[idx]

print(max_val)
# Out:
# 210

# %%
# 정답 코드
data = input()

# 첫 번째 문자를 숫자로 변경하여 대입 **굳이 list형태로 변환할 필요가 X -> string[idx]로 충분.
result = int(data[0])

for i in range(1, len(data)):
    num = int(data[i])
    if num <=1 or result <=1:
        result+=num
    else:
        result*=num
print(result)
# Out:
# 576

# %% [markdown]
# 2. **모험가 길드 문제**
#
#     한 마을에 모험가가 N명 있음. 모험가 길드에서는 N명의 모험가를 대상으로 ‘공포도’를 측정했는데, ‘공포도’가 높은 모험가는 쉽게 공포를 느껴 위험 상황에서 제대로 대처할 능력이 떨어짐.
#
#     모험가 길드 장인 동빈이는 모험가 그룹을 안전하게 구성하고자 공포도가 X인 모험가는 반드시 X명 이상으로 구성한 모험가 그룹에 참여해야 여행을 떠날 수 있도록 규정.
#
#     동빈이는 최대 몇 개의 모험가 그룹을 만들 수 있는지 궁금. N명의 모험가에 대한 정보가 주어졌을 때, 여행을 떠날 수 있는 그룹 수의 최댓값을 구하는 프로그램을 작성하시오.
#
#     입력 예시 1
#
#         5
#
#         2 3 1 2 2
#     출력 예시 1 - 그룹 1에 1,2,3인 모험가를 한 명씩 넣고, 그룹 2에 공포도가 2인 남은 두명을 넣게 되면 총 2개의 그룹을 만들 수 있음
#
#         2

# %%
# 내 코드
# 아이디어: 공포도가 1이면 혼자가도 ㄱㅊ음, 2면 2명이상, 3이면 3명 이상의 그룹 -> 공포도가 높은 사람을 포함하는 그룹부터 만들기

num = input()
score = list(map(int, input().split()))
score.sort()

result = 0  # 총 그룹의 수
count = 0   # 그룹 내 인원
for i in score:
    count+=1
    if i <= count:
        result+=1
        count=0

print(result)
# Out:
# 2
