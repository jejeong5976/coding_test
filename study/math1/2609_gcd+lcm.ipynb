# %% [markdown]
# ## 최대공약수와 최소공배수

# %%
# input
a,b = map(int,input().split())

# gcd
def gcd(a,b):
    if a%b==0:
        return b
    else:
        return gcd(b,a%b)

# lcm
def lcm(a,b):
    return a*b//gcd(a,b)

print(gcd(a,b))
print(lcm(a,b))
# Out:
# 6
# 72
